# %%
import constants
import QiskitNEQR
from qiskit import *
from qiskit.visualization import plot_histogram
from qiskit.tools.monitor import job_monitor

circuit : QuantumCircuit = QiskitNEQR.NEQR(constants.testimages[0]) 
simulator = Aer.get_backend('aer_simulator')
circuit = transpile(circuit, backend=simulator, optimization_level=2)
simulation = execute(circuit, simulator, shots=constants.ITR)
result = simulation.result()
counts = result.get_counts(circuit)
plot_histogram(counts)

# %%
circuit : QuantumCircuit = QiskitNEQR.NEQR(constants.testimages[2]) 
simulator = Aer.get_backend('aer_simulator')
circuit = transpile(circuit, backend=simulator, optimization_level=2)
simulation = execute(circuit, simulator, shots=constants.ITR)
result = simulation.result()
counts = result.get_counts(circuit)
plot_histogram(counts)

# %%
circuit : QuantumCircuit = QiskitNEQR.NEQR(constants.testimages[3]) 
simulator = Aer.get_backend('aer_simulator')
circuit = transpile(circuit, backend=simulator, optimization_level=2)
simulation = execute(circuit, simulator, shots=constants.ITR)
result = simulation.result()
counts = result.get_counts(circuit)
plot_histogram(counts)
